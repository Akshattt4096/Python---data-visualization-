# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshattt4096/Python---data-visualization-/blob/main/dsp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df= pd.read_csv('/insurance - insurance.csv')
df.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
print(plt.figure(figsize=(10,4),dpi=100))
sns.boxplot(x = "age", data=df)
# Out:
# Figure(1000x400)
# <Axes: xlabel='age'>

# %%
print(plt.figure(figsize=(10,4),dpi=100))
color_palette = sns.color_palette("Accent_r")
sns.set_palette(color_palette)
sns.countplot(x="region",data=df)
# Out:
# Figure(1000x400)
# <Axes: xlabel='region', ylabel='count'>

# %%
print(plt.figure(figsize=(10,4),dpi=100))
color_palette = sns.color_palette("cool")

sns.set_palette(color_palette)
sns.countplot(x="smoker",data=df)
# Out:
# Figure(1000x400)
# <Axes: xlabel='smoker', ylabel='count'>

# %%
print(plt.figure(figsize=(10,4),dpi=100))
color_palette = sns.color_palette("plasma")
sns.set_palette(color_palette)
sns.barplot(x="region", y="bmi",data=df)
# Out:
# Figure(1000x400)
# <Axes: xlabel='region', ylabel='bmi'>

# %%
plt.figure(figsize=(8, 8), dpi=100)

grp = dict(df.groupby('region').groups)
m = {}

# Build the dictionary first
for key, val in grp.items():
    m[key] = len(val)

# Plot AFTER loop
plt.title("Distribution of Region")
plt.pie(m.values(), labels=m.keys(), autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.show()

# %%
# Finding correlation
plt.figure(figsize=(10, 6), dpi=100)

color = sns.color_palette("magma")

numeric_df = df.select_dtypes(include='number')

sns.heatmap(numeric_df.corr(), vmax=0.9, annot=True, cmap=color)
plt.show()
